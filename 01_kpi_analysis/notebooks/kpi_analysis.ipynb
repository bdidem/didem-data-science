# %% [markdown]
# # E-commerce KPI Analysis

# %% [markdown]
# ##### Data Loading Section

# %%
import duckdb
import pandas as pd

# Load dataset
df = pd.read_csv("../data/ecommerce_data.csv")

# Register dataframe as DuckDB table
con = duckdb.connect()
con.register("orders", df)

# %% [markdown]
# ##### Query
# We compute total revenue and revenue per user to understand concentration.

# %%
# Run SQL
query = """
SELECT user_id,
       SUM(revenue) AS total_revenue,
       COUNT(*) AS num_orders
FROM orders
GROUP BY user_id
ORDER BY total_revenue DESC
"""

result = con.execute(query).df()
result.head()

# %% [markdown]
# ##### Insight
# Revenue is highly concentrated: top 20% users generate 65% of total revenue. Retention strategies should prioritize these segments.
